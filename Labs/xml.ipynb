# %%
import requests
from xml.dom.minidom import parse

# %%
page = requests.get("https://www.xnxx.com/")
print (page)
print("------------")
print (page.content)
# Out:
# <Response [200]>
# ------------
# ...

# %%
<xml version="1.0" encoding="UTF-8"?>
<Breakfast-Menu>
  <food>
    <name>Full Irish</name>
    <price>9.99</price>
    <calories>750</calories>
    <description>Sausage, Bacon, Egg, Pudding and Mushroom</description>
  </food>
  <food>
    <name>Eggs Benedict</name>
    <price>12.99</price>
    <calories>650</calories>
    <description>Poached Eggs on sourdough toast with hollandaise sauce</description>
  </food>
</Breakfast Menu>
# Out:
#   Cell In[1], line 1
#     <xml version="1.0" encoding="UTF-8"?>
#     ^
# SyntaxError: invalid syntax
